# %% [markdown]
# <a href="https://colab.research.google.com/github/dang-jessika/Twitch-Data-Analysis/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('twitchdata-update.csv')

df.head()
# Out:
#     Channel  Watch time(Minutes)  Stream time(minutes)  Peak viewers  \
# 0     xQcOW           6196161750                215250        222720
# 1  summit1g           6091677300                211845        310998
# 2    Gaules           5644590915                515280        387315
# 3  ESL_CSGO           3970318140                517740        300575
# 4      Tfue           3671000070                123660        285644
#
#    Average viewers  Followers  Followers gained  Views gained  Partnered  \
# 0            27716    3246298           1734810      93036735       True
# 1            25610    5310163           1370184      89705964       True
# 2            10976    1767635           1023779     102611607       True
# 3             7714    3944850            703986     106546942       True
# 4            29602    8938903           2068424      78998587       True
#
#    Mature    Language
# 0   False     English
# 1   False     English
# 2    True  Portuguese
# ...

# %%
print(df.isnull().sum())
lang_stats = df.groupby('Language')['Followers gained'].mean().sort_values(ascending = False)
print(lang_stats)
# Out:
# Channel                 0
# Watch time(Minutes)     0
# Stream time(minutes)    0
# Peak viewers            0
# Average viewers         0
# Followers               0
# Followers gained        0
# Views gained            0
# Partnered               0
# Mature                  0
# Language                0
# dtype: int64
# Language
# Spanish       570378.073529
# Arabic        479938.200000
# Turkish       259308.227273
# Portuguese    247165.573770
# English       203294.319588
# Italian       196034.411765
# French        181407.121212
# German        172197.020408
# Russian       136863.500000
# Polish        118359.666667
# Czech          92805.000000
# Hungarian      91755.000000
# Korean         86643.428571
# Japanese       59482.800000
# Thai           57836.454545
# Greek          51159.000000
# Slovak         37681.000000
# Other          29434.000000
# Finnish        29422.000000
# Chinese        28209.933333
# Swedish        25277.000000
# ...

# %%
ax=lang_stats.head(10).plot(kind='bar',color='purple')
plt.title('Top 10 Languages by Average Followers Gained')
plt.ylabel('Followers')
for container in ax.containers:
    ax.bar_label(container, fmt=lambda x: f'{x/1000:.1f}K')

plt.show()

# %%
maturity_stats = df.groupby('Mature')['Followers gained'].mean()
print(maturity_stats)
# Out:
# Mature
# False    222787.207792
# True     147706.017391
# Name: Followers gained, dtype: float64
